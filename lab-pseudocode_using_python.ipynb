# %% [markdown]
# # LAB | Pseudocode Using Python
#
# ## Overview
#
# This exercise will help you practice writing pseudocode and translating it into Python code. Pseudocode is a way to describe algorithms in a human-readable format, which can then be implemented in programming languages.

# %% [markdown]
# ### Exercise 1: Multiply Two Numbers
#
# Write a pseudocode to read two numbers and multiply them together. Then, write the equivalent Python code.

# %% [markdown]
# <!-- Add your pseudocode here -->

# %%
# pseudocode:

# BEGIN
#   READ number1
#   READ number2
#   SET result = number1 * number2
#   PRINT the product of number1 and number2 is: result
#   PRINT "Error: Please enter valid numbers!" if input is invalid
# END 

# python code with error handling:
try:
    # Read two numbers from user input
    number1 = float(input("Enter the first number: "))
    number2 = float(input("Enter the second number: "))
    
    # Multiply the numbers
    result = number1 * number2
    
    # Display the result
    print(f"The product of {number1} and {number2} is: {result}")
    
except ValueError:
    print("Error: Please enter valid numbers!")
# Out:
# The product of 3.0 and 4.0 is: 12.0

# %% [markdown]
# ### Exercise 2: Check Even or Odd
#
# Write pseudocode that checks if a number is even or odd and prints the result. Then, write the equivalent Python code.

# %% [markdown]
# <!-- Add your pseudocode here -->

# %%
# pseudocode:
# BEGIN
#  DEFINE function check_even_odd(number)
#    IF number MOD2 = 0 THEN
#       PRINT number is "Even"
#    ELSE
#       PRINT number is "Odd"
#  END FUNCTION

#  READ number from user input: 
#   TRY to CONVERT input to integer
#       CALL check_even_odd(number)
#       Print result
#   HANDLE invalid input
#       Print "Error: Please enter a valid number!" if input is invalid
#   END

# python code to check even or odd: (using function)

def check_even_odd(number):
    """Check if a number is even or odd and return the result as a string."""
    if number % 2 == 0:
        return "Even"
    else:
        return "Odd"
    
try:
    # Read a number from user input
    number = int(input("Enter a number: "))
    
    # Call the function and get the result
    result = check_even_odd(number)
    
    # Print the result
    print(f"The number {number} is {result}.")
except ValueError:
    print("Error: Please enter a valid integer!")
# Out:
# The number 5 is Odd.

# %% [markdown]
# ### Exercise 3: Sum of First N Natural Numbers
#
# Write pseudocode to calculate the sum of the first N natural numbers. Then, write the equivalent Python code.

# %% [markdown]
# <!-- Add your pseudocode here -->

# %%
# pseudocode
# BEGIN
#    START TRY BLOCK
#        DISPLAY "Enter a positive integer N: "
#        READ input_value
#        SET N = CONVERT_TO_INTEGER(input_value)
        
#        IF N < 0 THEN
#            RAISE ValueError WITH MESSAGE "N must be a positive integer!"
#        END IF
        
#        SET sum_N = (N × (N + 1)) ÷ 2
#        DISPLAY "The sum of the first " + N + " natural numbers is: " + sum_N
        
#    CATCH (ValueError exception)
#        IF exception_message = "N must be a positive integer!" THEN
#            DISPLAY "Error: N must be a positive integer!"
#        ELSE
#            DISPLAY "Error: Please enter a valid integer!"
#        END IF
#    END TRY-CATCH
# END

# %%
# pythoon code (using mathematical expression directly):
# mathematical formula:
#   Sum of first N natural numbers = N * (N + 1) / 2

# Python code (with proper error handling):
try:
    # Read N from user input
    N = int(input("Enter a positive integer N: "))
    
    if N < 0:
        raise ValueError("N must be a positive integer!")
    
    # Calculate the sum of the first N natural numbers
    sum_N = N * (N + 1) // 2
    
    # Display the result
    print(f"The sum of the first {N} natural numbers is: {sum_N}")
    
except ValueError as e:
    if str(e) == "N must be a positive integer!":
        print("Error: N must be a positive integer!")
    else:
        print("Error: Please enter a valid integer!")
# Out:
# The sum of the first 5 natural numbers is: 15

# %% [markdown]
# ### Exercise 4: Find Maximum of Three Numbers
#
# Write pseudocode that finds the maximum of three numbers entered by the user. Then, write the equivalent Python code.

# %% [markdown]
# <!-- Add your pseudocode here -->

# %%
# text
# BEGIN
#     READ num1, num2, num3
    
#     SET max_num = num1
    
#     IF num2 > max_num THEN
#         SET max_num = num2
#     END IF
    
#     IF num3 > max_num THEN
#         SET max_num = num3
#     END IF
    
#     PRINT "The maximum number is:", max_num
# END

# %%
# python
# Read three numbers from user input
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
num3 = float(input("Enter the third number: "))

# Find the maximum number
max_num = num1

if num2 > max_num:
    max_num = num2

if num3 > max_num:
    max_num = num3

# Display the result
print(f"The maximum number is: {max_num}")
# Out:
# The maximum number is: 5.0

# %% [markdown]
# ### Exercise 5: Count Vowels in a String
#
# Write pseudocode to count the number of vowels in a given string and print the count. Then, write the equivalent Python code.

# %% [markdown]
# <!-- Add your pseudocode here -->

# %%
# pseudocode
# text
# BEGIN
#    READ input_string
#    SET vowel_count = 0
#    SET vowels = "aeiouAEIOU"
    
#    FOR each character IN input_string DO
#        IF character IS IN vowels THEN
#            SET vowel_count = vowel_count + 1
#        END IF
#    END FOR
    
#    PRINT "Number of vowels:", vowel_count
# END

# python
# Read a string from user input
input_string = input("Enter a string/word/sentence: ")

# Initialize vowel count
vowel_count = 0
vowels = "aeiouAEIOU"

# Count vowels in the string
for char in input_string:
    if char.lower() in vowels:
        vowel_count += 1

# Display the result
print(f"Number of vowels: {vowel_count}")
# Out:
# Number of vowels: 10

# %% [markdown]
# ## Bonus Exercises
#
# ### Bonus Exercise 6: Reverse a String
#
# Write pseudocode to reverse a given string and print it out.

# %% [markdown]
# <!-- Add your pseudocode here -->

# %%
# pseudocode
# BEGIN
#    DISPLAY "Enter a string: "
#    READ input_string
    
#    SET reversed_string = EMPTY_STRING
#    SET string_length = LENGTH(input_string)
#    SET index = string_length - 1
    
#    WHILE index >= 0 DO
#        SET current_char = input_string[index]
#        SET reversed_string = reversed_string + current_char
#        SET index = index - 1
#    END WHILE
    
#    DISPLAY "Original: " + input_string
#    DISPLAY "Reversed: " + reversed_string
# END

# python
# Read input string
input_string = input("Enter a string/word/sentence: ")

# Initialize variables
reversed_string = ""
string_length = len(input_string)
index = string_length - 1

# Loop backwards using while loop
while index >= 0:
    current_char = input_string[index]
    reversed_string = reversed_string + current_char
    index = index - 1

# Print results
print("Original:", input_string)
print("Reversed:", reversed_string)
# Out:
# Original: bye bye
# Reversed: eyb eyb

# %% [markdown]
# ### Bonus Exercise 7: Print Multiplication Table of a Number
#
# Write pseudocode to print the multiplication table of a given number up to 10.

# %% [markdown]
# <!-- Add your pseudocode here -->

# %%
# pseudocode
# BEGIN
#    DISPLAY "Enter a number: "
#    READ number
    
#    DISPLAY "Multiplication table for", number, ":"
    
#    SET multiplier = 1
#    REPEAT
#        SET product = number * multiplier
#        DISPLAY number, " × ", multiplier, " = ", product
#        SET multiplier = multiplier + 1
#    UNTIL multiplier > 10
# END

# python
# DISPLAY "Enter a number: "
number = int(input("Enter a number: "))

# DISPLAY "Multiplication table for", number, ":"
print(f"Multiplication table for {number}:")

# SET multiplier = 1
multiplier = 1

# REPEAT
while True:
    # SET product = number * multiplier
    product = number * multiplier
    
    # DISPLAY number, " × ", multiplier, " = ", product
    print(f"{number} × {multiplier} = {product}")
    
    # SET multiplier = multiplier + 1
    multiplier = multiplier + 1
    
    # UNTIL multiplier > 10
    if multiplier > 10:
        break
# Out:
# Multiplication table for 3:
# 3 × 1 = 3
# 3 × 2 = 6
# 3 × 3 = 9
# 3 × 4 = 12
# 3 × 5 = 15
# 3 × 6 = 18
# 3 × 7 = 21
# 3 × 8 = 24
# 3 × 9 = 27
# 3 × 10 = 30

# %% [markdown]
# ### Bonus Exercise 8: Count Words in a String
#
# Write pseudocode that counts the words in a given string and prints the result.

# %%
# pseudocode
# BEGIN
#    DISPLAY "Enter a string: "
#    READ input_string
    
#    SET word_count = 0
#    SET previous_char = space
    
#    FOR i FROM 0 TO LENGTH(input_string) - 1 DO
#        SET current_char = input_string[i]
        
#        IF current_char IS NOT space AND previous_char IS space THEN
#            SET word_count = word_count + 1
#        END IF
        
#        SET previous_char = current_char
#    END FOR
    
#    PRINT "The string contains", word_count, "words"
# END

# python
# READ input_string
input_string = input("Enter a string: ")

# SET word_count = 0
word_count = 0
# SET previous_char = space
previous_char = ' '

# FOR i FROM 0 TO LENGTH(input_string) - 1 DO
for i in range(len(input_string)):
    # SET current_char = input_string[i]
    current_char = input_string[i]
    
    # IF current_char IS NOT space AND previous_char IS space THEN
    if current_char != ' ' and previous_char == ' ':
        # SET word_count = word_count + 1
        word_count += 1
    
    # SET previous_char = current_char
    previous_char = current_char

# PRINT "The string contains", word_count, "words"
print("The string contains", word_count, "words")
# Out:
# The string contains 1 words

# %% [markdown]
# <!-- Add your pseudocode here -->

# %% [markdown]
# ### Bonus Exercise 9: Find Factorial of a Number
#
# Write pseudocode that calculates the factorial of a given positive integer.

# %% [markdown]
# <!-- Add your pseudocode here -->

# %%
# pseudocode
# BEGIN
#    DISPLAY "Enter a positive integer: "
#    READ number
#    SET factorial = 1
    
#    IF number < 0 THEN
#        PRINT "Error: Factorial is not defined for negative numbers"
#    ELSE IF number = 0 THEN
#        PRINT "Factorial of 0 is 1"
#    ELSE
#       SET i = 1
#        WHILE i <= number DO
#            SET factorial = factorial * i
#            SET i = i + 1
#        END WHILE
#        PRINT "Factorial of", number, "is", factorial
#    END IF
# END

# python
# Read number from user input
number = int(input("Enter a positive integer: "))

# Initialize factorial
factorial = 1

# Check for valid input
if number < 0:
    print("Error: Factorial is not defined for negative numbers")
elif number == 0:
    print("Factorial of 0 is 1")
else:
    # Calculate factorial using while loop
    i = 1
    while i <= number:
        factorial = factorial * i
        i = i + 1
    
    print(f"Factorial of {number} is {factorial}")
# Out:
# Factorial of 8 is 40320

# %% [markdown]
# ### Bonus Exercise 10: FizzBuzz Problem
#
# Write pseudocode for the FizzBuzz problem where you print numbers from 1 to N but replace multiples of three with "Fizz" and multiples of five with "Buzz".

# %% [markdown]
# <!-- Add your pseudocode here -->

# %%
# pseudocode
# BEGIN
#    DISPLAY "Enter the value of N: "
#    READ N
    
#    FOR i FROM 1 TO N DO
#        SET output = EMPTY_STRING
        
#        IF i MOD 3 = 0 THEN
#            SET output = output + "Fizz"
#        END IF
        
#        IF i MOD 5 = 0 THEN
#            SET output = output + "Buzz"
#        END IF
        
#        IF output = EMPTY_STRING THEN
#            SET output = CONVERT_TO_STRING(i)
#        END IF
        
#        DISPLAY output
#    END FOR
# END

# python:
# Read N from user input
N = int(input("Enter the value of N: "))

# FizzBuzz using string concatenation
for i in range(1, N + 1):
    output = ""
    
    if i % 3 == 0:
        output += "Fizz"
    
    if i % 5 == 0:
        output += "Buzz"
    
    # If output is still empty, use the number
    if output == "":
        output = str(i)
    
    print(output)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz
# 101
# Fizz
# 103
# 104
# FizzBuzz
# 106
# 107
# Fizz
# 109
# Buzz
# Fizz
# 112
# 113
# Fizz
# Buzz
# 116
# Fizz
# 118
# 119
# FizzBuzz
# 121
# 122
# Fizz
# 124
# Buzz
# Fizz
# 127
# 128
# Fizz
# Buzz
# 131
# Fizz
# 133
# 134
# FizzBuzz
# 136
# 137
# Fizz
# 139
# Buzz
# Fizz
# 142
# 143
# Fizz
# Buzz
# 146
# Fizz
# 148
# 149
# FizzBuzz
# 151
# 152
# Fizz
# 154
# Buzz
# Fizz
# 157
# ...
